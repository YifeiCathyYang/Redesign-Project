# %% [markdown]
# <a href="https://colab.research.google.com/github/YifeiCathyYang/Redesign-Project/blob/main/SaaS_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import	matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/My Drive/Colab Notebooks/SaaS__sales/SaaS-Sales.csv")
print(data)
# Out:
#       Row ID          Order ID  Order Date  Date Key       Contact Name  \
# 0          1  EMEA-2024-152156   11/9/2024  20241109        Nathan Bell
# 1          2  EMEA-2024-152156   11/9/2024  20241109        Nathan Bell
# 2          3  AMER-2024-138688   6/13/2024  20240613     Deirdre Bailey
# 3          4  EMEA-2023-108966  10/11/2023  20231011         Zoe Hodges
# 4          5  EMEA-2023-108966  10/11/2023  20231011         Zoe Hodges
# ...      ...               ...         ...       ...                ...
# 9989    9990  EMEA-2022-110422   1/22/2022  20220122          Dan Allan
# 9990    9991  AMER-2025-121258   2/27/2025  20250227  Anthony Sanderson
# 9991    9992  AMER-2025-121258   2/27/2025  20250227  Anthony Sanderson
# 9992    9993  AMER-2025-121258   2/27/2025  20250227  Anthony Sanderson
# 9993    9994  AMER-2025-119914    5/5/2025  20250505   Jasmine Springer
#
#             Country           City Region Subregion  \
# ...

# %%
data.head()
# Out:
#    Row ID          Order ID  Order Date  Date Key    Contact Name  \
# 0       1  EMEA-2024-152156   11/9/2024  20241109     Nathan Bell
# 1       2  EMEA-2024-152156   11/9/2024  20241109     Nathan Bell
# 2       3  AMER-2024-138688   6/13/2024  20240613  Deirdre Bailey
# 3       4  EMEA-2023-108966  10/11/2023  20231011      Zoe Hodges
# 4       5  EMEA-2023-108966  10/11/2023  20231011      Zoe Hodges
#
#          Country           City Region Subregion            Customer  \
# 0        Ireland         Dublin   EMEA      UKIR   AnyCompany Energy
# 1        Ireland         Dublin   EMEA      UKIR   AnyCompany Energy
# 2  United States  New York City   AMER     NAMER      AnyCompany Oil
# 3        Germany      Stuttgart   EMEA   EU-WEST  Example Corp Power
# 4        Germany      Stuttgart   EMEA   EU-WEST  Example Corp Power
#
#    Customer ID Industry     Segment                 Product     License  \
# 0         1017   Energy  Enterprise         Marketing Suite  16GRM07R1K
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=data)
# Out:
# https://docs.google.com/spreadsheets/d/1PHyU28sx9hDKM4Oo8GQgcbxKJXdSBytJ_uJR51lzmGA/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1PHyU28sx9hDKM4Oo8GQgcbxKJXdSBytJ_uJR51lzmGA/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title Region vs Segment

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Segment'].value_counts()
    for x_label, grp in data.groupby('Region')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Region')
_ = plt.ylabel('Segment')
